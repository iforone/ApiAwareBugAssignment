 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Deepak Azad', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Deepak Azad', 'Dani Megert', 'Deepak Azad', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Raksha Vasisht', 'Deepak Azad', 'JDT-UI-Inbox', 'Dani Megert', 'Deepak Azad', 'Raksha Vasisht', 'Raksha Vasisht', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Rajesh', 'Raksha Vasisht', 'Raksha Vasisht', 'Dani Megert', 'Dani Megert', 'Raksha Vasisht', 'Markus Keller', 'Raksha Vasisht', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'JDT-UI-Inbox', 'Deepak Azad', 'Raksha Vasisht', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Deepak Azad', 'Raksha Vasisht', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Raksha Vasisht', 'Dani Megert', 'JDT-UI-Inbox', 'Raksha Vasisht', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Deepak Azad', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Dani Megert', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Deepak Azad', 'Deepak Azad', 'Dani Megert', 'Raksha Vasisht', 'Raksha Vasisht', 'Raksha Vasisht', 'Raksha Vasisht', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Deepak Azad', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Raksha Vasisht', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Dani Megert', 'Raksha Vasisht', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Deepak Azad', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Ferenc Hechler', 'Markus Keller', 'Dani Megert', 'Deepak Azad', 'Tomasz Zarna', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Achim Demelt', 'Dani Megert', 'Markus Keller', 'Benjamin Muskalla', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'JDT-UI-Inbox', 'Benjamin Muskalla', 'Benjamin Muskalla', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Dani Megert', 'Benjamin Muskalla', 'Benjamin Muskalla', 'Benjamin Muskalla', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Benjamin Muskalla', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Benno Baumgartner', 'Benno Baumgartner', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Tomasz Zarna', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Dani Megert', 'Markus Keller', 'Tomasz Zarna', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'JDT-UI-Inbox', 'Raksha Vasisht', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Mateusz Matela', 'Tomasz Zarna', 'Raksha Vasisht', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Raksha Vasisht', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Ferenc Hechler', 'JDT-UI-Inbox', 'Ferenc Hechler', 'Markus Keller', 'Dani Megert', 'Raksha Vasisht', 'Dani Megert', 'Markus Keller', 'Raksha Vasisht', 'JDT-UI-Inbox', 'Raksha Vasisht', 'Markus Keller', 'JDT-UI-Inbox', 'Raksha Vasisht', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'JDT-UI-Inbox', 'Tomasz Zarna', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Raksha Vasisht', 'Raksha Vasisht', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Raksha Vasisht', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Raksha Vasisht', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'JDT-UI-Inbox', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Benjamin Muskalla', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Dani Megert', 'Markus Keller', 'JDT-UI-Inbox', 'Dani Megert', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'Dani Megert', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Dani Megert', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Dani Megert', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Karsten Becker', 'Martin Aeschlimann', 'Karsten Becker', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Karsten Becker', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Karsten Becker', 'Karsten Becker', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Karsten Becker', 'Karsten Becker', 'Karsten Becker', 'Karsten Becker', 'Karsten Becker', 'Karsten Becker', 'Karsten Becker', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Karsten Becker', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Karsten Becker', 'Karsten Becker', 'Benno Baumgartner', 'Karsten Becker', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Karsten Becker', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Karsten Becker', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Karsten Becker', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Karsten Becker', 'Karsten Becker', 'Martin Aeschlimann', 'Markus Keller', 'Karsten Becker', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Karsten Becker', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Karsten Becker', 'Benno Baumgartner', 'Karsten Becker', 'Martin Aeschlimann', 'Karsten Becker', 'Karsten Becker', 'Krzysztof Michalski', 'Martin Aeschlimann', 'Markus Keller', 'Karsten Becker', 'Karsten Becker', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Karsten Becker', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Karsten Becker', 'Karsten Becker', 'Benno Baumgartner', 'Benno Baumgartner', 'Karsten Becker', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Karsten Becker', 'Benno Baumgartner', 'Karsten Becker', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Karsten Becker', 'Martin Aeschlimann', 'Karsten Becker', 'Michael D. Elder', 'Markus Keller', 'Karsten Becker', 'Karsten Becker', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Karsten Becker', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Tobias Widmer', 'Tobias Widmer', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Tobias Widmer', 'Tobias Widmer', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Benno Baumgartner', 'Tobias Widmer', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'JDT-UI-Inbox', 'Karsten Becker', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Karsten Becker', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Tobias Widmer', 'JDT-UI-Inbox', 'Krzysztof Michalski', 'Markus Keller', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Krzysztof Michalski', 'Krzysztof Michalski', 'Tomasz Zarna', 'Markus Keller', 'Tobias Widmer', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Tobias Widmer', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'Markus Keller', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Dani Megert', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Dani Megert', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Tobias Widmer', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Benno Baumgartner', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'JDT-UI-Inbox', 'Markus Keller', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Benno Baumgartner', 'Tobias Widmer', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Markus Keller', 'Benno Baumgartner', 'Benno Baumgartner', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Markus Keller', 'Tobias Widmer', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Tobias Widmer', 'Markus Keller', 'Martin Aeschlimann', 'Benno Baumgartner', 'Markus Keller', 'Tobias Widmer', 'Markus Keller', 'Markus Keller', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'JDT-UI-Inbox', 'Markus Keller', 'Tobias Widmer', 'JDT-UI-Inbox', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Benno Baumgartner', 'Tobias Widmer', 'Tobias Widmer', 'Markus Keller', 'JDT-UI-Inbox', 'Markus Keller', 'Tobias Widmer', 'Tobias Widmer', 'Markus Keller', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Markus Keller', 'Tobias Widmer', 'Markus Keller', 'Tobias Widmer', 'JDT-UI-Inbox', 'Markus Keller', 'Michael D. Elder', 'Markus Keller', 'Tom Hofmann', 'Benno Baumgartner', 'Markus Keller', 'Markus Keller', 'Dani Megert', 'Dani Megert', 'Tobias Widmer', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Benno Baumgartner', 'Tobias Widmer', 'Tobias Widmer', 'Benno Baumgartner', 'Dani Megert', 'Tom Hofmann', 'Michael D. Elder', 'Michael D. Elder', 'Benno Baumgartner', 'Tobias Widmer', 'Tobias Widmer', 'Dirk Baeumer', 'Tobias Widmer', 'Benno Baumgartner', 'Tobias Widmer', 'Benno Baumgartner', 'Tobias Widmer', 'Dirk Baeumer', 'Tobias Widmer', 'Tobias Widmer', 'Tobias Widmer', 'Markus Keller', '
 'Martin Aeschlimann', 'Dirk Baeumer', 'Dirk Baeumer', 'Till Bay', 'Till Bay', 'Adam Kiezun', 'Till Bay', 'Till Bay', 'Erich Gamma', 'Andre Weinand', 'Till Bay', 'Erich Gamma', 'JDT-UI-Inbox', 'Erich Gamma', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Erich Gamma', 'Erich Gamma', 'Erich Gamma', 'Dirk Baeumer', 'Adam Kiezun', 'Till Bay', 'Erich Gamma', 'Till Bay', 'Till Bay', 'Till Bay', 'Till Bay', 'Till Bay', 'Till Bay', 'Erich Gamma', 'Till Bay', 'Dani Megert', 'Dirk Baeumer', 'Till Bay', 'Erich Gamma', 'Martin Aeschlimann', 'Dani Megert', 'Dirk Baeumer', 'Dani Megert', 'Erich Gamma', 'Dirk Baeumer', 'Till Bay', 'JDT-UI-Inbox', 'Dirk Baeumer', 'Dirk Baeumer', 'Till Bay', 'Till Bay', 'Erich Gamma', 'Till Bay', 'Erich Gamma', 'Martin Aeschlimann', 'Dani Megert', 'JDT-UI-Inbox', 'Erich Gamma', 'Andre Weinand', 'Dani Megert', 'Till Bay', 'Till Bay', 'Till Bay', 'Erich Gamma', 'Till Bay', 'Till Bay', 'Dani Megert', 'Erich Gamma', 'Dani Megert', 'Dani Megert', 'Erich Gamma', 'Andre Weinand', 'JDT-UI-Inbox', 'Dirk Baeumer', 'Dani Megert', 'Adam Kiezun', 'Dani Megert', 'Claude Knaus', 'Erich Gamma', 'Erich Gamma', 'Martin Aeschlimann', 'Claude Knaus', 'Claude Knaus', 'Adam Kiezun', 'Dani Megert', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Adam Kiezun', 'Martin Aeschlimann', 'Till Bay', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Adam Kiezun', 'Dirk Baeumer', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Erich Gamma', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dirk Baeumer', 'Dirk Baeumer', 'Erich Gamma', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Martin Aeschlimann', 'Dirk Baeumer', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Dani Megert', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Erich Gamma', 'Dirk Baeumer', 'Adam Kiezun', 'Erich Gamma', 'Dirk Baeumer', 'Dirk Baeumer', 'Adam Kiezun', 'Adam Kiezun', 'Dirk Baeumer', 'Kai-Uwe Maetzel', 'Martin Aeschlimann', 'Dani Megert', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dirk Baeumer', 'Martin Aeschlimann', 'Dani Megert', 'Martin Aeschlimann', 'Erich Gamma', 'Dani Megert', 'Erich Gamma', 'Martin Aeschlimann', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Dirk Baeumer', 'Claude Knaus', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Dani Megert', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Martin Aeschlimann', 'Dirk Baeumer', 'Claude Knaus', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Dani Megert', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Dani Megert', 'Erich Gamma', 'Martin Aeschlimann', 'Adam Kiezun', 'Claude Knaus', 'Claude Knaus', 'Adam Kiezun', 'Adam Kiezun', 'Dani Megert', 'Martin Aeschlimann', 'Unknown User', 'Dirk Baeumer', 'Adam Kiezun', 'Martin Aeschlimann', 'Dani Megert', 'Claude Knaus', 'Dirk Baeumer', 'Claude Knaus', 'Erich Gamma', 'Andre Weinand', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Erich Gamma', 'Erich Gamma', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Markus Huebscher', 'Dani Megert', 'Markus Huebscher', 'Dani Megert', 'Adam Kiezun', 'Markus Huebscher', 'Adam Kiezun', 'Markus Huebscher', 'Markus Huebscher', 'Dani Megert', 'Markus Huebscher', 'Markus Huebscher', 'Markus Huebscher', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Dani Megert', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Claude Knaus', 'Martin Aeschlimann', 'Erich Gamma', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Claude Knaus', 'Adam Kiezun', 'Martin Aeschlimann', 'Adam Kiezun', 'Erich Gamma', 'Dani Megert', 'Dirk Baeumer', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Adam Kiezun', 'Dani Megert', 'Adam Kiezun', 'Erich Gamma', 'Adam Kiezun', 'Dani Megert', 'Erich Gamma', 'Martin Aeschlimann', 'Claude Knaus', 'Adam Kiezun', 'Claude Knaus', 'Martin Aeschlimann', 'Kai-Uwe Maetzel', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Kai-Uwe Maetzel', 'Martin Aeschlimann', 'Erich Gamma', 'Kai-Uwe Maetzel', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Adam Kiezun', 'Kai-Uwe Maetzel', 'Dani Megert', 'Dani Megert', 'Adam Kiezun', 'Adam Kiezun', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Andre Weinand', 'Adam Kiezun', 'Claude Knaus', 'Martin Aeschlimann', 'Claude Knaus', 'Dirk Baeumer', 'Erich Gamma', 'Dani Megert', 'Dani Megert', 'Kai-Uwe Maetzel', 'Dani Megert', 'Martin Aeschlimann', 'Adam Kiezun', 'Dani Megert', 'Erich Gamma', 'Martin Aeschlimann', 'Erich Gamma', 'Martin Aeschlimann', 'Erich Gamma', 'Erich Gamma', 'Adam Kiezun', 'Kai-Uwe Maetzel', 'Adam Kiezun', 'Claude Knaus', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Dani Megert', 'Adam Kiezun', 'Erich Gamma', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Martin Aeschlimann', 'Claude Knaus', 'Dani Megert', 'Adam Kiezun', 'JDT-UI-Inbox', 'Adam Kiezun', 'Dani Megert', 'Dirk Baeumer', 'Adam Kiezun', 'Erich Gamma', 'Dirk Baeumer', 'Adam Kiezun', 'Dani Megert', 'Dani Megert', 'Adam Kiezun', 'Adam Kiezun', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Claude Knaus', 'Adam Kiezun', 'Claude Knaus', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Erich Gamma', 'Adam Kiezun', 'Dirk Baeumer', 'Claude Knaus', 'Adam Kiezun', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Claude Knaus', 'Dirk Baeumer', 'Dirk Baeumer', 'Dirk Baeumer', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Martin Aeschlimann', 'Andre Weinand', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Erich Gamma', 'Martin Aeschlimann', 'Adam Kiezun', 'Andre Weinand', 'Erich Gamma', 'Erich Gamma', 'Claude Knaus', 'Dani Megert', 'Martin Aeschlimann', 'Erich Gamma', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann', 'Kai-Uwe Maetzel', 'Martin Aeschlimann', 'JDT-UI-Inbox', 'Claude Knaus', 'Martin Aeschlimann', 'Claude Knaus', 'Kai-Uwe Maetzel', 'Kai-Uwe Maetzel', 'Erich Gamma', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Dirk Baeumer', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Dani Megert', 'Adam Kiezun', 'Martin Aeschlimann', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Dirk Baeumer', 'Kai-Uwe Maetzel', 'Andre Weinand', 'Martin Aeschlimann', 'Andre Weinand', 'Claude Knaus', 'Martin Aeschlimann', 'Adam Kiezun', 'Martin Aeschlimann', 'Claude Knaus', 'Claude Knaus', 'Claude Knaus', 'Claude Knaus', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'Claude Knaus', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Claude Knaus', 'JDT-UI-Inbox', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Adam Kiezun', 'Kai-Uwe Maetzel', 'Dirk Baeumer', 'Claude Knaus', 'Claude Knaus', 'Adam Kiezun', 'Claude Knaus', 'Claude Knaus', 'Martin Aeschlimann', 'Dirk Baeumer', 'Dirk Baeumer', 'Erich Gamma', 'Erich Gamma', 'Erich Gamma', 'Dirk Baeumer', 'Dani Megert', 'Erich Gamma', 'Martin Aeschlimann', 'Kai-Uwe Maetzel', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Martin Aeschlimann', 'Adam Kiezun', 'Dani Megert', 'Kai-Uwe Maetzel', 'Kai-Uwe Maetzel', 'Dani Megert', 'Dani Megert', 'Dani Megert', 'Martin Aeschlimann', 'Kai-Uwe Maetzel', 'Kai-Uwe Maetzel', 'Erich Gamma', 'JDT-UI-Inbox', 'Erich Gamma', 'Erich Gamma', 'Claude Knaus', 'Erich Gamma', 'Adam Kiezun', 'Erich Gamma', 'Adam Kiezun', 'Claude Knaus', 'Martin Aeschlimann', 'Adam Kiezun', 'Adam Kiezun', 'Claude Knaus', 'Claude Knaus', 'Andre Weinand', 'Adam Kiezun', 'Claude Knaus', 'Claude Knaus', 'Claude Knaus', 'Erich Gamma', 'Martin Aeschlimann', 'Erich Gamma', 'Adam Kiezun', 'Adam Kiezun', 'Martin Aeschlimann']
list( set(temp1) - set(temp2))

list(set(temp1) & set(temp2))

import numpy as np
import matplotlib.pyplot as plt
x = range(1, 11)
y = []
for each in x:
    y.append(2**each * 0.7 / (math.factorial(each + 1)))

print('Values of x: ', x)
print('Values of y: ', y)
plt.plot(x, y)
plt.title("Quadratic Function")
plt.xlabel("Values of x")
plt.ylabel("Values of y")
plt.show()
# Out:
# Values of x:  range(1, 11)
# Values of y:  [0.7, 0.4666666666666666, 0.2333333333333333, 0.09333333333333332, 0.03111111111111111, 0.008888888888888889, 0.0022222222222222222, 0.0004938271604938272, 9.876543209876543e-05, 1.7957351290684622e-05]

# %%
import pandas as pd
import numpy as np
import math 
import statistics
from pandas import Timestamp
import math

# %%
# get stat for -old or new and then compare
def get_stat_for(file, authors, label='-new', extra='', time_a = 1, time_b = 1, time_c = 1):
    pd.set_option("display.max_columns", None)
    df = pd.read_csv(file)
    count = 0
    total = 0
    indexes = []
    for (index, row) in df.iterrows():

        
        # calcualte total scores
        total_scores = {'history': 0, 'api': 0, 'code': 0, 'api_s': 0}

        for i in range(1, 11):
            h = row['history_at_' + str(i) + '_v']
            c = row['code_at_' + str(i) + '_v']
            a = row['api_at_' + str(i) + '_v']

            if str(h) != 'nan':
                total_scores['history'] += h
            if str(c) != 'nan':
                total_scores['code'] += c
            if str(a) != 'nan':
                total_scores['api'] += a
                
        # calcualte and rank developer scores
        scores = {}        
        for i in range(1, 11):
            h = row['history_at_' + str(i) + '_v']
            h_developer = row['history_at_' + str(i)]
            c = row['code_at_' + str(i) + '_v']
            c_developer = row['code_at_' + str(i)]
            a = row['api_at_' + str(i) + '_v']
            a_developer = row['api_at_' + str(i)]

            if str(h_developer) != 'nan':
                if str(h) == 'nan' or h == 0 or total_scores['history'] <= 0:
                    scores[a_developer] = scores.get(a_developer, []) + [0]
                else:
                    scores[h_developer] = scores.get(h_developer, []) + [time_a * float(h * 100 / total_scores['history'])]

            if str(c_developer) != 'nan':
                if str(c) == 'nan' or c == 0 or total_scores['code'] <= 0:
                    scores[a_developer] = scores.get(a_developer, []) + [0]
                else:
                    scores[c_developer] = scores.get(c_developer, []) + [time_b * float(c * 100 / total_scores['code'])]


            if str(a_developer) != 'nan':
                if str(a) == 'nan' or a == 0 or total_scores['api'] <= 0:
                    scores[a_developer] = scores.get(a_developer, []) + [0]
                else: #
                    # row['assignees'] == row['api_at_1'] and 
                    #row['jaccard_score']  = row['jaccard_score'] * 2 / i
                    #x = row['jaccard_score']
                    #if row['assignees'] == row['api_at_1']:
                    #    x = 1
#                     x = row['jaccard_score']
#                     if i == 1:
#                         x = 2 * row['jaccard_score']
                    scores[a_developer] = scores.get(a_developer, []) + [time_c * row['jaccard_score'] * float(a * 100 / total_scores['api'])]
                    pass

                
        # calculate the total
        for index_, score in scores.items():
            if len(score) == 0:
                scores[index_] = 0
            else:
                scores[index_] = sum(score)  ## ** (1/float(len(score)))

        sort = sorted(scores.items(), key=lambda x: x[1], reverse=True)

        chosen = ''
        if len(sort) != 0:
            chosen = sort[0][0]

        if chosen == row['assignees']:
            count += 1
            indexes.append(index)
#         if chosen != row['assignees']:
#             if (row['assignees'] == row['api_at_1']):
#                 print(row['assignees'])
            
            
            
        previous = row['assignees']
        total += 1

        if row['assignees'] not in authors:
            authors[row['assignees']] = {
                'total-new': 0, 'count_differently-new': 0, 'count-new': 0, 'count_history-new': 0, 'count_code-new': 0, 'count_api-new': 0,
                'total-old': 0, 'count_differently-old': 0, 'count-old': 0, 'count_history-old': 0, 'count_code-old': 0, 'count_api-old': 0,
                }

        authors[row['assignees']]['total' + label] += 1
        if row['assignees'] == row['history_at_1']:
            authors[row['assignees']]['count_history' + label] += 1
        if row['assignees'] == row['code_at_1']:
            authors[row['assignees']]['count_code' + label] += 1
        if row['assignees'] == row['api_at_1']:
            authors[row['assignees']]['count_api' + label] += 1
        if 1 == row['at_1']:
            authors[row['assignees']]['count' + label] += 1
        if 0 < len(sort) and sort[0][0] == row['assignees']:
            authors[row['assignees']]['count_differently' + label] += 1
            

        
        previous = row['chosen']
        previous_time = row['report_time']
        previous_component = row['component']
   

    if extra == 'index':
        return indexes
    if extra == 'ratio':
        return count / total

    print(label)
    print(count)
    print(count / total)
    print(total)
    return authors



authors_ = {}
after = get_stat_for('../../data/output/jdt_direct.csv', authors_, '-new', 'index', 1, 1, 1)
before = get_stat_for('../../data/output/jdt_direct-best-mapper.csv', authors_, '-old', 'index', 1, 1, 1)

# %%
diff = [x for x in before if x not in after]

print(before)

print(after)

print(diff)
# Out:
# [0, 1, 3, 5, 7, 8, 9, 10, 11, 14, 15, 17, 18, 19, 20, 22, 27, 28, 31, 32, 33, 39, 40, 43, 45, 46, 48, 49, 50, 54, 56, 57, 58, 59, 63, 65, 68, 69, 70, 71, 72, 73, 75, 76, 81, 83, 84, 85, 86, 87, 88, 89, 90, 93, 94, 95, 97, 98, 99, 100, 101, 102, 103, 108, 109, 110, 111, 112, 115, 117, 120, 121, 128, 130, 131, 133, 137, 139, 140, 142, 144, 146, 147, 148, 152, 156, 160, 161, 162, 163, 164, 166, 168, 171, 172, 174, 176, 181, 182, 183, 195, 196, 197, 200, 201, 203, 205, 206, 207, 209, 211, 214, 215, 216, 217, 218, 220, 221, 222, 228, 229, 233, 239, 240, 241, 242, 244, 246, 250, 252, 254, 255, 256, 257, 258, 259, 261, 262, 264, 265, 270, 271, 277, 278, 279, 280, 286, 288, 289, 291, 292, 294, 299, 301, 302, 306, 309, 310, 315, 322, 327, 329, 331, 332, 333, 334, 336, 338, 341, 342, 344, 345, 346, 347, 349, 351, 352, 354, 355, 357, 358, 359, 362, 363, 365, 366, 367, 369, 370, 373, 374, 376, 377, 381, 383, 386, 388, 391, 396, 398, 399, 403, 404, 405, 406, 410, 411, 416, 417, 420, 421, 429, 430
# ...

# %%
result = pd.DataFrame()
df = pd.read_csv('../../data/output/jdt_direct.csv')
for d in diff:
    temp = df.loc[d]
    result = result.append(temp)
result.to_csv('assess-xxx.csv')

# %%
from itertools import product
x=100
y=1
tries = [p/x for p in range(0, int(x*y))] + [1.0]
listOLists = [tries, tries, tries]

best_ratio = 0
best_ratio_code = 0
allvalues = {}
for list in product(*listOLists):
    ratio = get_stat_for('../../data/output/jdt_direct.csv', {}, '-new', 'ratio', list[0], list[1], list[2])
    key = str(list[0]) + '_' + str(list[1]) + '_' + str(list[2])
    allvalues[key] = ratio
    print(ratio)
    if best_ratio < ratio:
        best_ratio = ratio
        best_ratio_code = key

print('result:')
print(best_ratio)
print(best_ratio_code)
print(allvalues)
# Out:
# 0.23166666666666666
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# ...

# %%
from itertools import product
x=10
y=1
tries = [p/x for p in range(0, int(x*y))] + [1.0]
listOLists = [tries, tries, tries]

best_ratio = 0
best_ratio_code = 0
for list in product(*listOLists):
    ratio = get_stat_for('../../data/output/jdt_direct.csv', {}, '-new', 'ratio', list[0], list[1], list[2])
    print(ratio)
    if best_ratio < ratio:
        best_ratio = ratio
        best_ratio_code = str(list[0]) + '_' + str(list[1]) + '_' + str(list[2])

print('result:')
print(best_ratio)
print(best_ratio_code)
# Out:
# 0.23166666666666666
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.36833333333333335
# 0.42333333333333334
# 0.43833333333333335
# 0.435
# 0.43666666666666665
# 0.4266666666666667
# 0.42333333333333334
# 0.42333333333333334
# 0.4216666666666667
# 0.4216666666666667
# 0.42
# 0.4166666666666667
# 0.42333333333333334
# 0.43833333333333335
# 0.43833333333333335
# 0.435
# 0.435
# 0.435
# 0.43666666666666665
# 0.42833333333333334
# 0.4266666666666667
# 0.42333333333333334
# 0.42333333333333334
# 0.42333333333333334
# 0.44
# 0.43833333333333335
# 0.43833333333333335
# 0.43833333333333335
# 0.43333333333333335
# 0.435
# 0.435
# 0.435
# 0.43666666666666665
# 0.43166666666666664
# 0.42333333333333334
# 0.43666666666666665
# 0.43833333333333335
# 0.44
# 0.43833333333333335
# 0.44333333333333336
# 0.435
# 0.43333333333333335
# 0.435
# ...
